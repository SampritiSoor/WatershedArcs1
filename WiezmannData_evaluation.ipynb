# %%
import matplotlib 
# %matplotlib inline
dpi = matplotlib.rcParams['figure.dpi']

from segmentation_codes.evaluationPlots import generateEvaluationPlot

# %%
noOfObj=2
imageName='sakurag060521_dysn34'
generateEvaluationPlot(imageName,noOfObj,dpi)

# %%
noOfObj=1
imageName='100_0109'
generateEvaluationPlot(imageName,noOfObj,dpi)
