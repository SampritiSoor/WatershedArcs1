# %%
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt

import matplotlib 
# %matplotlib inline
dpi = matplotlib.rcParams['figure.dpi']
figsize = .25*image.shape[1] / float(dpi), .25*image.shape[0] / float(dpi)

from segmentation_codes.evaluationMetrics import getSeg

# %%
image=np.array(Image.open('mosa.tif'),dtype=np.int32)
plt.figure(figsize=figsize)
plt.imshow(image,cmap='plasma')
plt.show()

imageFrame=np.full(image.shape,True)
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        if image[i,j]==0:
            imageFrame[i,j]=False

# %%
Hierarchies=get_hierSeg_WSarcs_arcRemove(image,nhood=8,frame=imageFrame)

# %%
for l in range(len(Hierarchies)):
    boun=(255-Hierarchies[l])/255
    plt.figure(figsize=figsize)
    plt.imshow(getSeg(boun,imageFrame),cmap='plasma')
    plt.show()
